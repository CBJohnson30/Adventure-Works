# %% [markdown]
# # Code Snips
# Chucks of code that I will be using is multiple other scripts or notebooks

# %% [markdown]
# ### Connection to Adventure Works DB

# %%
from db_connector import AdventureWorksDB

# %%
db = AdventureWorksDB()

# %%
query = '''
    SELECT TOP 10 *
    FROM Production.WorkOrder
'''

# %%
df = db.query(query)

df.head()
